# %% [markdown]
# # Traffic signs detection project #
# Section 3 of our project: Masks and AdaBoost.

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA
from sklearn.ensemble import AdaBoostClassifier

# %%
path_base = os.getcwd() + "\\newFeatures"
train, test = np.load(os.path.join(path_base,'featuresTrain.npy')), np.load(os.path.join(path_base,'featuresTest.npy'))

x1 = train
x1 = x1.astype("float32") / 255
rows, cols = (4170, 2025)
train = np.array([[0]*cols]*rows)
train = train.astype("float32")
jump = 0
for i in range(0,rows):
    for j in range(0, 45):
        for k in range(0, 45):
            train[i][jump] = x1[i][j][k]
            jump = jump + 1
    jump = 0


x2 = test
x2 = x2.astype("float32") / 255
rows, cols = (1998, 2025)
test = np.array([[0]*cols]*rows)
test = test.astype("float32")
jump = 0
for i in range(0,rows):
    for j in range(0, 45):
        for k in range(0, 45):
            test[i][jump] = x2[i][j][k]
            jump = jump + 1
    jump = 0

# Load the classification vector (classes):

path_img = os.getcwd()
f = open(path_img + "\\tsrd-train-y.txt", "r")
str = f.read()

lines = str.split("\n")
arr = []
for line in lines:
    arr.append(int(line.split(";")[7]))
    
Train_classes = []
for i in range(58):
    for k in range(arr.count(i)):
        Train_classes.append(i)

f = open(path_img + "\\newtest-y.txt", "r")
str = f.read()

lines = str.split("\n")
arr = []
for line in lines:
    arr.append(int(line.split(";")[7]))
    
Test_classes = []
for i in range(58):
    for k in range(arr.count(i)):
        Test_classes.append(i)

# %%
# A function that returns the name of the traffic sign, based in it's class
def getNames(num):
    match num:
        case 0:
            return '5-MPH'
        case 1:
            return '15-MPH'
        case 2:
            return '30-MPH'
        case 3:
            return '40-MPH'
        case 4:
            return '50-MPH'
        case 5:
            return '60-MPH'
        case 6:
            return '70-MPH'
        case 7:
            return '80-MPH'
        case 8:
            return 'Turn left/straight forbidden'
        case 9:
            return 'Turn right/straight forbidden'
        case 10:
            return 'Cannot go straight'
        case 11:
            return 'Cannot turn left'
        case 12:
            return 'Cannot turn right/left'
        case 13:
            return 'Cannot turn right'
        case 14:
            return 'Cannot bypass'
        case 15:
            return 'Cannot do u-turn'
        case 16:
            return 'No cars allowed'
        case 17:
            return 'No music allowed'
        case 18:
            return 'Black 40-MPH'
        case 19:
            return 'Black 50-MPH'
        case 20:
            return 'Can only go straight/right'
        case 21:
            return 'Can only go straight'
        case 22:
            return 'Can only turn left'
        case 23:
            return 'Can only turn right/left'
        case 24:
            return 'Can only turn right'
        case 25:
            return 'Can only keep left'
        case 26:
            return 'Can only keep right'
        case 27:
            return 'A roundabout ahead'
        case 28:
            return 'Cars allowed here'
        case 29:
            return 'Music allowed here'
        case 30:
            return 'Bicycle area'
        case 31:
            return 'Can u-turn here'
        case 32:
            return 'Split ahead'
        case 33:
            return'Traffic light ahead'
        case 34:
            return 'Warning ahead'
        case 35:
            return 'Warning: People crossing the road here'
        case 36:
            return 'Warning: Bikes crossing the road here'
        case 37:
            return 'Warning: Kids are playing around'
        case 38:
            return 'Warning: Right foreclosure ahead'
        case 39:
            return 'Warning: Left foreclosure ahead'
        case 40:
            return 'Warning: Downhill'
        case 41:
            return 'Warning: Uphill'
        case 42:
            return 'Warning: Something Chinese ahead'
        case 43:
            return 'Warning: Turn right'
        case 44:
            return 'Warning: Turn left'
        case 45:
            return 'Warning: Tree'
        case 46:
            return 'Warning: Distorted road'
        case 47:
            return 'Warning: Trains pass by'
        case 48:
            return 'Warning: Road works ahead'
        case 49:
            return 'Warning" Very Distorted road'
        case 50:
            return 'Warning: Jail ahead'
        case 51:
            return 'Warning: Bumping trucks ahead'
        case 52:
            return 'Warning: Red Chinese ahead'
        case 53:
            return 'No entrance from both sides'
        case 54:
            return 'No parking allowed'
        case 55:
            return 'No entrance'
        case 56:
            return 'Something Chinese in a red-white triangle'
        case 57:
            return 'Chinese no entrance'
    return 'unnown'

# %%
target_names = []
for i in range(0, 58):
    target_names.append(getNames(i))

n_components = 200
SIZE = 45

print(
    "Extracting the top %d eigenfaces from %d faces" % (n_components, train.shape[0])
)
pca = PCA(n_components=n_components, svd_solver="randomized", whiten=True).fit(train)
eigenfaces = pca.components_.reshape((n_components, SIZE, SIZE))
X_train_pca = pca.transform(train)
X_test_pca = pca.transform(test)

# Train the model:
clf = AdaBoostClassifier(n_estimators=100, random_state=0)
clf = clf.fit(X_train_pca, Train_classes)
# Out:
# Extracting the top 200 eigenfaces from 4170 faces

# %%
print("Predicting traffic signs on the test set")
y_pred = clf.predict(X_test_pca)
print(classification_report(Test_classes, y_pred, target_names=target_names))
# Out:
# Predicting traffic signs on the test set
#                                            precision    recall  f1-score   support
#
#                                     5-MPH       0.00      0.00      0.00        14
#                                    15-MPH       0.00      0.00      0.00        12
#                                    30-MPH       0.00      0.00      0.00        60
#                                    40-MPH       0.00      0.00      0.00        84
#                                    50-MPH       0.00      0.00      0.00        58
#                                    60-MPH       0.00      0.00      0.00        50
#                                    70-MPH       0.00      0.00      0.00        30
#                                    80-MPH       0.50      0.08      0.14        50
#              Turn left/straight forbidden       0.00      0.00      0.00        14
#             Turn right/straight forbidden       0.00      0.00      0.00         1
# ...

# %%
def plot_gallery(images, titles, h, w, n_row=3, n_col=4):
    """Helper function to plot a gallery of portraits"""
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=0.01, right=0.99, top=0.90, hspace=0.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i].reshape((h, w)), cmap=plt.cm.gray)
        plt.title(titles[i], size=12, color='w')
        plt.xticks(())
        plt.yticks(())

def title(y_pred, y_test, target_names, i):
    pred_name = target_names[y_pred[i]].rsplit(" ", 1)[-1]
    true_name = target_names[y_test[i]].rsplit(" ", 1)[-1]
    return "predicted: %s\ntrue:      %s" % (pred_name, true_name)

prediction_titles = [
    title(y_pred, Test_classes, target_names, i) for i in range(y_pred.shape[0])
]
 
plot_gallery(test, prediction_titles, SIZE, SIZE)

# %%
# Show the eigenfaces
eigenface_titles = ["eigenface %d" % i for i in range(eigenfaces.shape[0])]
plot_gallery(eigenfaces, eigenface_titles, SIZE, SIZE)
plt.show()

# %% [markdown]
# # Next file (Project4) contains Neural Network use.
